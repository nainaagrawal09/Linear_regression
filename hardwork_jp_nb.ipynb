# %%
# !pip install pandas
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Collecting pandas
#   Downloading pandas-1.3.0-cp39-cp39-win_amd64.whl (10.2 MB)
# Requirement already satisfied: pytz>=2017.3 in c:\users\naina agrawal\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\naina agrawal\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\naina agrawal\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\naina agrawal\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.3.0
# WARNING: You are using pip version 20.2.3; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\users\naina agrawal\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ## Section 1 - Load and Visualise the Data
#
# * Download
# - Load
# - Visualise
# - Normalisation

# %%
# Load
X = pd.read_csv('Linear_X_Train.csv')
y = pd.read_csv('Linear_Y_Train.csv')

# Convert X,Y to Numpy arrays
X = X.values
y = y.values

# Normalisation
u = X.mean()
std = X.std()
X = (X-u)/std


# Visualise
plt.style.use('seaborn')
plt.scatter(X,y,color='orange')
plt.title("Hardwork vs Performance Graph")
plt.xlabel("Hardwork")
plt.ylabel("Performance")
plt.show()

# %% [markdown]
# ## Section 2- Linear Regression

# %%
def hypothesis(x,theta):
    y_ = theta[0] + theta[1]*x
    return y_

def gradient(X,Y,theta):
    m = X.shape[0]
    grad = np.zeros((2,))
    for i in range(m):
        x = X[i]
        y_ = hypothesis(x,theta)
        y = Y[i]
        grad[0] += (y_ - y)
        grad[1] += (y_ - y)*x
    return grad/m

def error(X,Y,theta):
    m = X.shape[0]
    total_error = 0.0
    for i in range(m):
        y_ = hypothesis(X[i],theta)
        total_error += (y_ - Y[i])**2
        
    return (total_error/m)
    

def gradientDescent(X,Y,max_steps=100,learning_rate =0.1):
    
    theta = np.zeros((2,))
    error_list = []
    theta_list = []
    
   
    for i in range(max_steps):
        
        # Compute grad
        grad = gradient(X,Y,theta)
        e = error(X,Y,theta)[0]
        
        #Update theta
        theta[0] = theta[0] - learning_rate*grad[0]
        theta[1] = theta[1] - learning_rate*grad[1]
        # Storing the theta values during updates
        theta_list.append((theta[0],theta[1]))
        error_list.append(e)
        
    return theta,error_list,theta_list

# %%
theta,error_list,theta_list = gradientDescent(X,y)

# %%
theta
# Out:
# array([ 0.6838508 , 79.90361453])

# %% [markdown]
# #### theta_list

# %%
plt.plot(error_list)
plt.title("Reduction error over time")
plt.show()

# %% [markdown]
# ## Section -3 Predictions and best line

# %%
y_ = hypothesis(X,theta)
print(y_)
# Out:
# [[-19.5733619 ]
#  [-43.69571729]
#  [ 86.4848761 ]
#  ...
#  [-20.85044708]
#  [138.70197319]
#  [-35.87897262]]

# %% [markdown]
# #### Training + Predictions

# %%
plt.scatter(X,y)
plt.plot(X,y_,color='orange',label="Prediction")
plt.legend()
plt.show()

# %% [markdown]
# #### Load the test data

# %%
X_test = pd.read_csv('Linear_X_Test.csv').values
y_test = hypothesis(X_test,theta)

# %%
df = pd.DataFrame(data=y_test,columns=["y"])

# %%
df.to_csv('y_prediction.csv',index=False)

# %% [markdown]
# ## Section - 4 Computing Score

# %%
def r2_score(Y,Y_):
    num = np.sum((Y-Y_)**2)
    denom = np.sum((Y- Y.mean())**2)
    score = (1- num/denom)
    return score*100

# %%
r2_score(y,y_)
# Out:
# 97.09612226971643
